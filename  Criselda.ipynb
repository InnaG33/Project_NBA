# %%
# Dependencies and Setup
import pandas as pd

#load the files
players_data_to_load = "resources/Players.csv"
playdata_data_to_load = "resources/player_data.csv"
seasonstats_data_to_load = "resources/Seasons_Stats.csv"

#read the dataframes
players_data = pd.read_csv(players_data_to_load)
playdata_data = pd.read_csv(playdata_data_to_load)
seasonstats_data = pd.read_csv(seasonstats_data_to_load)

#rename the ondex columns to make sure they are the same 
players_data = players_data.rename(columns={"Players": "Player", "collage": "college"})
playdata_data = playdata_data.rename(columns={'name': 'Player'})
seasonstats_data = seasonstats_data.rename(columns={'name': 'Player'})

#Remove rows with incomplete data for season stats
seasonstats_data1 = seasonstats_data[seasonstats_data['Year'] >= 1982]

#merge the files
nba_merge1 = pd.merge(players_data, playdata_data, how="left", on=["Player", "Player"])
nba_merge2 = pd.merge(nba_merge1, seasonstats_data, how="left", on=["Player", "Player"])
nba_merge2
# Out:
#        Unnamed: 0_x             Player  height_x  weight_x  \
# 0                 0    Curly Armstrong     180.0      77.0
# 1                 0    Curly Armstrong     180.0      77.0
# 2                 1       Cliff Barker     188.0      83.0
# 3                 1       Cliff Barker     188.0      83.0
# 4                 1       Cliff Barker     188.0      83.0
# ...             ...                ...       ...       ...
# 25292          3917      Troy Williams     198.0      97.0
# 25293          3918       Kyle Wiltjer     208.0     108.0
# 25294          3919  Stephen Zimmerman     213.0     108.0
# 25295          3920        Paul Zipser     203.0      97.0
# 25296          3921        Ivica Zubac     216.0     120.0
#
#                              college_x    born      birth_city  \
# 0                   Indiana University  1918.0             NaN
# 1                   Indiana University  1918.0             NaN
# 2               University of Kentucky  1921.0        Yorktown
# ...
